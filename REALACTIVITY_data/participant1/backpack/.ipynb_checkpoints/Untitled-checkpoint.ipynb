# %%
import csv
import pandas as pd
import datetime;
import time;

# %%
from datetime import datetime

# %%
data = pd.read_csv('session2.csv');
# Out:
# /home/grads/d/doddapanenipc/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,6,16,19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'])
data['time'] = [d.time() for d in data['Timestamp']]
#data['time'] = pd.to_datetime(data['time']);

# %%
participant = 'p1';
location = 'backpack';

# %%
labels = pd.read_csv('participant1_session1.csv');
labels['start_time'] = pd.to_datetime(labels['start_time'])
labels['end_time'] = pd.to_datetime(labels['end_time'])

labels.sort_values(by=['start_time'])

labels['start_time']=labels['start_time']
labels['start_time'] = [d.time() for d in labels['start_time']]
labels['end_time']=labels['end_time']
labels['end_time'] = [d.time() for d in labels['end_time']]
#
print(labels)
#pd.DatetimeIndex(labels['start_time']).time
#print(labels);
# Out:
#              context start_time  end_time
# 0      sitting_chair   21:21:55  21:25:00
# 1            jumping   21:33:00  21:33:10
# 2            jumping   21:33:30  21:33:40
# 3            jumping   21:34:00  21:34:10
# 4            jumping   21:34:30  21:34:40
# 5            jumping   21:35:00  21:35:10
# 6           standing   21:25:30  21:28:30
# 7            walking   21:29:00  21:32:00
# 8      sitting_floor   21:36:00  21:39:00
# 9   walk_oneshoe_off   21:40:00  21:43:00
# 10         stairs_up   21:45:00  21:46:35
# 11         stairs_up   21:49:30  21:51:35
# 12       stairs_down   21:47:10  21:49:10
# 13       stairs_down   21:51:50  21:53:10
# 14        lying_down   21:59:30  22:02:30
# 15          sleeping   22:07:00  22:10:00
# 16           writing   22:20:00  22:23:00
# 17     elevator_down   22:37:25  22:37:55
# 18     elevator_down   22:38:00  22:38:25
# 19     elevator_down   22:40:30  22:41:20
# 20     elevator_down   22:41:20  22:41:45
# 21     elevator_down   22:42:40  22:42:55
# 22          using_pc   22:24:00  22:27:00
# 23        talk_phone   22:31:30  22:34:30
# 24       elevator_up   22:36:40  22:37:15
# 25       elevator_up   22:38:05  22:38:45
# 26       elevator_up   22:39:35  22:40:00
# 27       elevator_up   22:40:40  22:41:10
# 28       elevator_up   22:42:00  22:42:20
# 29           reading   22:27:30  22:30:30
# 30    hand_to_pocket   22:12:45  22:12:55
# 31    hand_to_pocket   22:13:05  22:13:05
# 32    hand_to_pocket   22:13:25  22:13:35
# 33    hand_to_pocket   22:13:45  22:13:55
# 34    hand_to_pocket   22:14:05  22:14:15
# 35    hand_to_pocket   22:14:25  22:14:35
# 36    hand_to_pocket   22:14:45  22:14:55
# 37    hand_to_pocket   22:21:05  22:21:15
# 38    hand_to_pocket   22:21:25  22:21:35
# 39    hand_to_pocket   22:21:45  22:21:55
# 40    hand_to_pocket   22:22:05  22:22:15
# 41    hand_to_pocket   22:22:25  22:22:35
# 42    hand_to_pocket   22:22:45  22:22:55
# 43    hand_to_pocket   22:17:05  22:17:15
# 44    hand_to_pocket   22:17:25  22:17:35
# 45    pocket_to_hand   22:12:55  22:13:05
# 46    pocket_to_hand   22:13:15  22:13:25
# 47    pocket_to_hand   22:13:35  22:13:45
# 48    pocket_to_hand   22:13:55  22:13:55
# 49    pocket_to_hand   22:14:15  22:14:25
# 50    pocket_to_hand   22:14:35  22:14:45

# %%
def partition(label,start_time,end_time,df):
    mask = (data['time'] > start_time) & (data['time'] <= end_time);
    df_sub = data.loc[mask];
    print(df_sub);
    sLength = len(df_sub['time']);
    df_sub['label']=label;
    df_sub['participant']=participant;
    df_sub['location']=location;
    df_sub = df_sub.reset_index()
    #df_sub['Timestamp']= df_sub['Timestamp']-df_sub['Timestamp'][0];
    #print(df_sub);
    return(df_sub);

# %%
#for x in range(0,len(labels)):
for x in range(0,1):
    print(x)
    tofile = partition(labels['context'][x],labels['start_time'][x],labels['end_time'][x],data);
    filename = 'p1_'+labels['context'][x]+str(x)+'.csv';
    print(filename);
    tofile.to_csv(filename)
# Out:
# 0
#            index                                              $type Activity  \
# 406821  14686383  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406822  14686384  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406823  14686385  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406824  14686386  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406825  14686387  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406826  14686388  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406827  14686389  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406828  14686390  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406829  14686391  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406830  14686392  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406831  14686393  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406832  14686394  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406833  14686395  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406834  14686396  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406835  14686397  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406836  14686398  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406837  14686399  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406838  14686400  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406839  14686401  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406840  14686402  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406841  14686403  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406842  14686404  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406843  14686405    Sensus.Probes.Context.LightDatum, SensusAndroid      NaN
# 406844  14686406  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406845  14686407  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406846  14686408  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 406847  14686409  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406848  14686410  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 406849  14686411  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 406850  14686412  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# ...          ...                                                ...      ...
# 645475  20471378  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645476  20471379  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645477  20471380  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645478  20471381  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645479  20471382  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645480  20471383  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645481  20471384  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645482  20471385  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645483  20471386  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645484  20471387  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645485  20471388  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645486  20471389  Sensus.Probes.Location.AltitudeDatum, SensusAn...      NaN
# 645487  20471390  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645488  20471391  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645489  20471392  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645490  20471393  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645491  20471394  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645492  20471395  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645493  20471396  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645494  20471397  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645495  20471398  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645496  20471399    Sensus.Probes.Context.LightDatum, SensusAndroid      NaN
# 645497  20471400  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645498  20471401  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
# 645499  20471402  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645500  20471403  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645501  20471404  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645502  20471405  Sensus.Probes.Movement.AccelerometerDatum, Sen...      NaN
# 645503  20471406  Sensus.Probes.Location.CompassDatum, SensusAnd...      NaN
# 645504  20471407  Sensus.Probes.Movement.GyroscopeDatum, SensusA...      NaN
#
#         Altitude  Brightness     BuildId Confidence  Decibels  \
# 406821       NaN         NaN  1545015808        NaN       NaN
# 406822       NaN         NaN  1545015808        NaN       NaN
# 406823       NaN         NaN  1545015808        NaN       NaN
# 406824       NaN         NaN  1545015808        NaN       NaN
# 406825       NaN         NaN  1545015808        NaN       NaN
# 406826       NaN         NaN  1545015808        NaN       NaN
# 406827       NaN         NaN  1545015808        NaN       NaN
# 406828       NaN         NaN  1545015808        NaN       NaN
# 406829       NaN         NaN  1545015808        NaN       NaN
# 406830       NaN         NaN  1545015808        NaN       NaN
# 406831       NaN         NaN  1545015808        NaN       NaN
# 406832       NaN         NaN  1545015808        NaN       NaN
# 406833       NaN         NaN  1545015808        NaN       NaN
# 406834       NaN         NaN  1545015808        NaN       NaN
# 406835       NaN         NaN  1545015808        NaN       NaN
# 406836       NaN         NaN  1545015808        NaN       NaN
# 406837       NaN         NaN  1545015808        NaN       NaN
# 406838       NaN         NaN  1545015808        NaN       NaN
# 406839       NaN         NaN  1545015808        NaN       NaN
# 406840       NaN         NaN  1545015808        NaN       NaN
# 406841       NaN         NaN  1545015808        NaN       NaN
# 406842       NaN         NaN  1545015808        NaN       NaN
# 406843       NaN         0.0  1545015808        NaN       NaN
# 406844       NaN         NaN  1545015808        NaN       NaN
# 406845       NaN         NaN  1545015808        NaN       NaN
# 406846       NaN         NaN  1545015808        NaN       NaN
# 406847       NaN         NaN  1545015808        NaN       NaN
# 406848       NaN         NaN  1545015808        NaN       NaN
# 406849       NaN         NaN  1545015808        NaN       NaN
# 406850       NaN         NaN  1545015808        NaN       NaN
# ...          ...         ...         ...        ...       ...
# 645475       NaN         NaN  1545015808        NaN       NaN
# 645476       NaN         NaN  1545015808        NaN       NaN
# 645477       NaN         NaN  1545015808        NaN       NaN
# 645478       NaN         NaN  1545015808        NaN       NaN
# 645479       NaN         NaN  1545015808        NaN       NaN
# 645480       NaN         NaN  1545015808        NaN       NaN
# 645481       NaN         NaN  1545015808        NaN       NaN
# 645482       NaN         NaN  1545015808        NaN       NaN
# 645483       NaN         NaN  1545015808        NaN       NaN
# 645484       NaN         NaN  1545015808        NaN       NaN
# 645485       NaN         NaN  1545015808        NaN       NaN
# 645486 -96.04523         NaN  1545015808        NaN       NaN
# 645487       NaN         NaN  1545015808        NaN       NaN
# 645488       NaN         NaN  1545015808        NaN       NaN
# 645489       NaN         NaN  1545015808        NaN       NaN
# 645490       NaN         NaN  1545015808        NaN       NaN
# 645491       NaN         NaN  1545015808        NaN       NaN
# 645492       NaN         NaN  1545015808        NaN       NaN
# 645493       NaN         NaN  1545015808        NaN       NaN
# 645494       NaN         NaN  1545015808        NaN       NaN
# 645495       NaN         NaN  1545015808        NaN       NaN
# 645496       NaN         0.0  1545015808        NaN       NaN
# 645497       NaN         NaN  1545015808        NaN       NaN
# 645498       NaN         NaN  1545015808        NaN       NaN
# 645499       NaN         NaN  1545015808        NaN       NaN
# 645500       NaN         NaN  1545015808        NaN       NaN
# 645501       NaN         NaN  1545015808        NaN       NaN
# 645502       NaN         NaN  1545015808        NaN       NaN
# 645503       NaN         NaN  1545015808        NaN       NaN
# 645504       NaN         NaN  1545015808        NaN       NaN
#
#                 DeviceId DeviceManufacturer       ...         \
# 406821  52064ec0937dc30b            samsung       ...
# 406822  52064ec0937dc30b            samsung       ...
# 406823  52064ec0937dc30b            samsung       ...
# 406824  52064ec0937dc30b            samsung       ...
# 406825  52064ec0937dc30b            samsung       ...
# 406826  52064ec0937dc30b            samsung       ...
# 406827  52064ec0937dc30b            samsung       ...
# 406828  52064ec0937dc30b            samsung       ...
# 406829  52064ec0937dc30b            samsung       ...
# 406830  52064ec0937dc30b            samsung       ...
# 406831  52064ec0937dc30b            samsung       ...
# 406832  52064ec0937dc30b            samsung       ...
# 406833  52064ec0937dc30b            samsung       ...
# 406834  52064ec0937dc30b            samsung       ...
# 406835  52064ec0937dc30b            samsung       ...
# 645486       NaN  2019-02-09  21:24:59.989548
# 645487  0.122806  2019-02-09  21:24:59.989830
# 645488       NaN  2019-02-09  21:24:59.990772
# 645489  0.120121  2019-02-09  21:24:59.991003
# 645490 -0.001569  2019-02-09  21:24:59.991246
# 645491 -0.000347  2019-02-09  21:24:59.992746
# 645492       NaN  2019-02-09  21:24:59.993310
# 645493  0.120853  2019-02-09  21:24:59.993525
# 645494  0.000875  2019-02-09  21:24:59.995601
# 645495       NaN  2019-02-09  21:24:59.996246
# 645496       NaN  2019-02-09  21:24:59.996472
# 645497  0.121097  2019-02-09  21:24:59.996697
# 645498  0.000264  2019-02-09  21:24:59.997302
# 645499       NaN  2019-02-09  21:24:59.998065
# 645500  0.121830  2019-02-09  21:24:59.998290
# 645501       NaN  2019-02-09  21:24:59.998781
# 645502  0.122074  2019-02-09  21:24:59.998999
# 645503       NaN  2019-02-09  21:24:59.999496
# 645504 -0.000347  2019-02-09  21:24:59.999705
#
# [238684 rows x 30 columns]
# /home/grads/d/doddapanenipc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/grads/d/doddapanenipc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# p1_sitting_chair0.csv

# %%
print(data)

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-a2c004fd620f> in <module>()
# ----> 1 datetime_object = datetime.strptime('1:33:03',  '%I:%M%M:%S%S')
#       2 print(datetime_object);
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     340         if not format_regex:
#     341             try:
# --> 342                 format_regex = _TimeRE_cache.compile(format)
#     343             # KeyError raised when a bad format is found; can be specified as
#     344             # \\, in which case it was a stray % but with a space after it
#
# ~/anaconda3/lib/python3.7/_strptime.py in compile(self, format)
#     270     def compile(self, format):
#     271         """Return a compiled re object for the format string."""
# --> 272         return re_compile(self.pattern(format), IGNORECASE)
#     273
#     274 _cache_lock = _thread_allocate_lock()
#
# ~/anaconda3/lib/python3.7/re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# ~/anaconda3/lib/python3.7/re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
#     288         if len(_cache) >= _MAXCACHE:
#
# ~/anaconda3/lib/python3.7/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~/anaconda3/lib/python3.7/sre_parse.py in parse(str, flags, pattern)
#     928
#     929     try:
# --> 930         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     931     except Verbose:
#     932         # the VERBOSE flag was switched on inside the pattern.  to be
#
# ~/anaconda3/lib/python3.7/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     424     while True:
#     425         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 426                            not nested and not items))
#     427         if not sourcematch("|"):
#     428             break
#
# ~/anaconda3/lib/python3.7/sre_parse.py in _parse(source, state, verbose, nested, first)
#     811                     group = state.opengroup(name)
#     812                 except error as err:
# --> 813                     raise source.error(err.msg, len(name) + 1) from None
#     814             sub_verbose = ((verbose or (add_flags & SRE_FLAG_VERBOSE)) and
#     815                            not (del_flags & SRE_FLAG_VERBOSE))
#
# error: redefinition of group name 'M' as group 3; was group 2 at position 48

# %%
print(data);
