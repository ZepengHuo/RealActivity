# %%
import os, json
import pandas as pd
def partition(label,start_time,end_time,df):
    mask = (df['Timestamp'] > start_time) & (df['Timestamp'] <= end_time);
    df_sub = df.loc[mask];
    sLength = len(df_sub['Timestamp']);
    df_sub['label']=label;
    df_sub['participant']='p2'
    df_sub = df_sub.reset_index()
    df_sub['Timestamp']= df_sub['Timestamp']-df_sub['Timestamp'][0];
    #print(df_sub);
    return(df_sub);

df = pd.read_csv('session2.csv');

df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df= df.sort_values(by=['Timestamp'],ascending=True);
print(df['Timestamp']);

startingtime = df['Timestamp'][6785057]
print(startingtime)

df['Timestamp'] = df['Timestamp'] - startingtime;

print(df['Timestamp'])

df2= df.reset_index();

print(df2['Timestamp']);

print(df2);

import datetime
from time import sleep
a = datetime.timedelta(minutes=1)
count_row = df2.shape[0]

print(df2['Timestamp'][1646]);
print(df2['Timestamp'][103045]);
print(df2['Timestamp'][4237000]);
print(df2['Timestamp'][7826715])
#print(df['index'][1646]);
#print(df['index'][1646]);
#print(df['index'][1646]);

print(df2['Timestamp'][4237318] - df2['Timestamp'][103046])
print(df2['Timestamp'][7826715] - df2['Timestamp'][4237319]);

#timestamps = df2['Timestamp'];
df2.plot(y='Timestamp', use_index=True)

session1 = df2[103046:4237318];
print(session1['Timestamp'])
print(session1);

session2 = df2[4237319:7826715];
print(session2);

import csv

labels_list =[];
labels_starting_time=[];
labels_ending_time=[];
labels_list2 =[];
labels_starting_time2=[];
labels_ending_time2=[];
with open('participant1_session1.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        labels_list.append(row[0]);
        labels_starting_time.append(row[1]);
        labels_ending_time.append(row[2]);
        #line_count+=;
    print(f'Processed {line_count} lines.')

with open('session2_labels.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        labels_list2.append(row[0]);
        labels_starting_time2.append(row[1]);
        labels_ending_time2.append(row[2]);
        #line_count+=;
    print(f'Processed {line_count} lines.')
print(labels_list2);
print(labels_starting_time2);
print(labels_ending_time2);

session1final = session1.reset_index();
session1final['Timestamp']= session1final['Timestamp']-session1final['Timestamp'][0];
session1final = session1final.drop(columns=['level_0']);
print(session1final)

session2final = session2.reset_index();
session2final['Timestamp']= session2final['Timestamp']-session2final['Timestamp'][0];
session2final = session2final.drop(columns=['level_0']);
print(session2final)

for x in range(0,len(labels_list)):
    tofile = partition(labels_list[x],labels_starting_time[x],labels_ending_time[x],session1final);
    filename = 'p1_'+labels_list[x]+str(x)+'.csv';
    print(filename);
    tofile.to_csv(filename)

for x in range(0,len(labels_list2)):
    tofile = partition(labels_list2[x],labels_starting_time2[x],labels_ending_time2[x],session2final);
    filename = 'p1_'+labels_list2[x]+str(x)+'.csv';
    print(filename);
    tofile.to_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c5b293cf61df> in <module>()
#      12     return(df_sub);
#      13
# ---> 14 df = pd.read_csv('session2.csv');
#      15
#      16 df['Timestamp'] = pd.to_datetime(df['Timestamp'])
#
# ...
